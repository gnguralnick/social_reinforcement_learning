# %%
from environments.cleanup_env import CleanupEnv
from models.random import RandomModel
from test import test
# Out:
# 2023-09-24 14:03:17,956	WARNING deprecation.py:50 -- DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!

# %%
num_agents = 20
env = CleanupEnv(num_agents=num_agents)

# %%
models = { str(i): RandomModel(env, 1, None, 'random-' + str(i)) for i in range(num_agents) }

# %%
test(models, env, 10, num_agents, 0, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 test(models, env, 10, num_agents, 0, 1)
#
# File ~/git/social_reinforcement_learning/test.py:17, in test(models, env, num_episodes, num_agents, eps, eps_decay_factor)
#      14 score = defaultdict(int)
#      16 while not all_done:
# ---> 17     env.render()
#      18     action_dict = {}
#      19     for agent in range(num_agents):
#
# File ~/git/social_reinforcement_learning/environments/cleanup_env.py:320, in CleanupEnv.render(self)
#     318 ax.grid(which='major', axis='both', linestyle='-', color='k', linewidth=1)
#     319 ax.set_xticks(np.arange(-.5, self.width, 1))
# --> 320 ax.set_yticks(np.arange(-.5, self.height, 1))
#     321 # if not labels:
#     322 plt.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
#
# ...
